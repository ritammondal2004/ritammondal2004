# %% [markdown]
# <a href="https://colab.research.google.com/github/ritammondal2004/ritammondal2004/blob/main/python_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Write a code to create a string with your name and print it

# %%
string = input("enter your name: ")
print(string)
# Out:
# enter your name: efe
# efe

# %% [markdown]
# 2.Write a code to find the length of the string "Hello World"

# %%
s = "Hello world"
cnt = 0
for i in s:
  cnt+=1
print(cnt)
# Out:
# 16

# %% [markdown]
# 3.Write a code to slice the first 3 characters from the string "Python Programming"

# %%
s = 'python Programming'
print(s[:3])
# Out:
# pyt

# %% [markdown]
#  4.Write a code to convert the string "hello" to uppercase

# %%
s = "hello"
print(s.upper())
# Out:
# HELLO

# %% [markdown]
# 5.Write a code to replace the word "apple" with "orange" in the string "I like apple"

# %%
str = "I like apple"
print(str.replace("apple","orange"))
# Out:
# I like orange

# %% [markdown]
# 6.Write a code to create a list with numbers 1 to 5 and print it

# %%
input_s = input("enter numbers separated by spaces: ")
list = input_s.split()
print([int(x) for x in list])
# Out:
# enter numbers separated by spaces: 1    2 3   4   9
# [1, 2, 3, 4, 9]

# %% [markdown]
# 7.Write a code to append the number 10 to the list [1, 2, 3, 4]

# %%
list = [1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8.Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

# %%
list = [1,2,3,4,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9.Write a code to access the second element in the list ['a', 'b', 'c', 'd']

# %%
list = ['a', 'b', 'c', 'd']
print(list[1])
# Out:
# b

# %% [markdown]
# 10.Write a code to reverse the list [10, 20, 30, 40, 50]

# %%
list = [10, 20, 30, 40, 50]
print(list[::-1])
# Out:
# [40, 30, 20]

# %% [markdown]
# 11.Write a code to create a tuple with the elements 10, 20, 30 and print it

# %%
tuple = (10,20,30)
print(tuple)
# Out:
# (10, 20, 30)
